# %%
import requests
api_key='29dd5320e8a84706ba853625242802'
city='vijayawada'
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
a=input("enter city:")
response=requests.get(url)
data=response.json()
(data)
# Out:
# {'location': {'name': 'Vijayawada',
#   'region': 'Andhra Pradesh',
#   'country': 'India',
#   'lat': 16.52,
#   'lon': 80.62,
#   'tz_id': 'Asia/Kolkata',
#   'localtime_epoch': 1709100369,
#   'localtime': '2024-02-28 11:36'},
#  'current': {'last_updated_epoch': 1709100000,
#   'last_updated': '2024-02-28 11:30',
#   'temp_c': 30.0,
#   'temp_f': 86.0,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 5.6,
#   'wind_kph': 9.0,
#   'wind_degree': 120,
#   'wind_dir': 'ESE',
#   'pressure_mb': 1014.0,
#   'pressure_in': 29.94,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 59,
#   'cloud': 25,
#   'feelslike_c': 29.0,
#   'feelslike_f': 84.2,
#   'vis_km': 6.0,
#   'vis_miles': 3.0,
#   'uv': 8.0,
#   'gust_mph': 7.5,
#   'gust_kph': 12.0}}

# %%
type(data)
# Out:
# dict

# %%
import requests
api_key='29dd5320e8a84706ba853625242802'
city=input("enter city:")
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)
data=response.json()
(data)
if(response==200):
  print("city name not found")
else:
  print("City:",data["location"]["name"])
  print("State:",data["location"]["region"])
  print("Country:",data["location"]["country"])
  print("Temperature in celsius:",data["current"]["temp_c"])
  print("wind speed:",data["current"]["wind_mph"])
  print("wind direction:",data["current"]["wind_dir"])
  print("Humidity:",data["current"]["humidity"])
  print("feels like:",data["current"]["feelslike_c"])
  print("cloud:",data["current"]["cloud"])
# Out:
# enter city:guntur
# City: Guntur
# State: Andhra Pradesh
# Country: India
# Temperature in celsius: 31.0
# wind speed: 6.9
# wind direction: E
# Humidity: 52
# feels like: 29.4
# cloud: 25

# %%
import requests
api="febae5cf2fmsh9a7aa211271e28ep18dbcejsn14287ac2f8c0"
url="https://myallies-breaking-news-v1.p.rapidapi.com/GetCompanyDetailsBySymbol"
response=requests.get(url)
data=response.json()
data
# Out:
# {'message': 'Invalid API key. Go to https://docs.rapidapi.com/docs/keys for more info.'}

# %%
import requests
url="https://myallies-breaking-news-v1.p.rapidapi.com/GetCompanyDetailsBySymbol"
headers = {
	"X-RapidAPI-Key": "febae5cf2fmsh9a7aa211271e28ep18dbcejsn14287ac2f8c0",
	"X-RapidAPI-Host": "myallies-breaking-news-v1.p.rapidapi.com"
}
response=requests.get(url,headers=headers)
data=response.json()
data
# Out:
# {'messages': 'The API is unreachable, please contact the API provider',
#  'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}
