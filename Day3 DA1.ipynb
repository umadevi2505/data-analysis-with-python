# %%
import pandas as pd
import seaborn as sns

# %%
sb=pd.read_csv("/content/df.csv")
sb
# Out:
#     Unnamed: 0   Names Initials  SEM1  SEM2  SEM3 Grade  Placed   average
# 0            0     Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1            1  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2            2  Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 3            3    Mary        N   7.7   8.0   NaN     B       0       NaN
# 4            4    Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5            5     Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6            6  Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7            7    Mari        N   7.7   8.0   7.1     B       1  7.600000
# 8            8    Jess        K   NaN   9.1   9.9    A+       1       NaN
# 9            9  Rajini        M   NaN   9.1   9.3     A       0       NaN
# 10          10   Kiran        V   NaN   9.3   9.2     A       0       NaN
# 11          11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# ...

# %%
p1=sns.lineplot(x='Names',y='SEM1',data=sb)

# %%
sns.relplot(data=sb,x="Names",y="SEM1",col="Placed")

# %%
#create a rel plot using age as y axis,index as xaxis,separated by class
sb1=pd.read_excel("/content/diabetes.xlsx")
sb1["index"]=range(0,768)
sns.relplot(data=sb1,y="age",x="index",col='class')

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='time',palette='pastel')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='size',style='time',palette='bright')

# %%
abc=sns.load_dataset("dowjones")
sns.relplot(data=abc,x='Date',y='Price',kind='line')

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
sns.relplot(data=fmri,x='timepoint',y='signal')

# %%
sns.catplot(data=tips,x='time',y='total_bill',kind='violin',hue='smoker')

# %%
sns.catplot(data=tips,x='time',y='total_bill',kind='box',hue='smoker')
